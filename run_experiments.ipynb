# %% [markdown]
# # HybridStackPPI Experiments (Unified Pipeline)
#
# Notebook này dùng các hàm đã chuẩn hoá trong `pipelines/` và `experiments/run.py`.
# - Split tránh leak (protein-level/cluster-level) và chuẩn hoá cặp PPI (sort P1/P2).
# - Motif local embedding dùng **max pooling**.
# - class_weight đã đồng bộ.

# %%
from importlib import reload

from experiments import run as exp_run
from pipelines.feature_engine import EmbeddingComputer, FeatureEngine
from pipelines.builders import define_stacking_columns, create_stacking_pipeline

# Reload để phản ánh thay đổi code nếu chỉnh sửa
reload(exp_run)
# Out:
# <module 'experiments.run' from '/media/SAS/Van/ppis/experiments/run.py'>

# %% [markdown]
# ## Cấu hình đường dẫn & tham số chung

# %%
H5_CACHE_FILE = 'cache/esm2_embeddings.h5'
ESM_MODEL = 'facebook/esm2_t33_650M_UR50D'
CACHE_VERSION = 'v3'

# BioGrid datasets packaged with the repo
BIOGRID_HUMAN_FASTA = 'data/BioGrid/Human/human_dict.fasta'
BIOGRID_HUMAN_PAIR = 'data/BioGrid/Human/human_pairs.tsv'

BIOGRID_YEAST_FASTA = 'data/BioGrid/Yeast/yeast_dict.fasta'
BIOGRID_YEAST_PAIR = 'data/BioGrid/Yeast/yeast_pairs.tsv'

N_JOBS = -1  # dùng tất cả CPU, đổi nếu cần

# %% [markdown]
# ## Khởi tạo FeatureEngine và cột stacking

# %%
embedding_computer = EmbeddingComputer(model_name=ESM_MODEL)
feature_engine = FeatureEngine(h5_cache_path=H5_CACHE_FILE, embedding_computer=embedding_computer)
interp_cols, embed_cols = define_stacking_columns(feature_engine, pairing_strategy='concat')

model_factory = lambda n_jobs: create_stacking_pipeline(
    interp_cols=interp_cols,
    embed_cols=embed_cols,
    n_jobs=n_jobs,
    use_selector=True,
)
# Out:
# Loading protein language model: facebook/esm2_t33_650M_UR50D...
# 2025-11-30 11:03:45.994848: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-30 11:03:46.436309: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-30 11:03:47.783914: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t33_650M_UR50D and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ESM2 model loaded successfully on CPU.
# Initializing Sequence-Only Hybrid Feature Engine...
# Fetching and compiling ELM motifs from API: http://elm.eu.org/elms/elms_index.tsv...
# ✅ Successfully loaded and compiled 353 motifs from ELM database.
# Feature Engine ready.

# %% [markdown]
# ## 1) 5-Fold Cross-Validation (protein-level)

# %%
cv_results = exp_run.run_experiment(
    fasta_path=BIOGRID_HUMAN_FASTA,
    pairs_path=BIOGRID_HUMAN_PAIR,
    h5_cache_path=H5_CACHE_FILE,
    model_factory=model_factory,
    pairing_strategy='concat',
    n_splits=5,
    esm_model_name=ESM_MODEL,
    n_jobs=N_JOBS,
    cache_version=CACHE_VERSION,
)
cv_results
# Out:
# 📦 PHASE: LOADING FEATURES FROM CACHE
# ------------------------------------------------------------
#   [Cache] Loading feature matrix from cache/human_human_pairs_facebook_esm2_t33_650m_ur50d_concat_v2_features.h5...
#   [Cache] Load complete. X=(62328, 7140), y=(62328,)
#
# ================================================================================
# 🚀 EXPERIMENT: 5-FOLD CV (PROTEIN-LEVEL SPLIT - NO LEAKAGE)
# ================================================================================
# Generating 5-fold splits based on 38869 unique proteins...
#   Fold 1: Train Pairs=39636, Val Pairs=2713 (Leakage Check: 0 overlap)
#   Fold 2: Train Pairs=40205, Val Pairs=2534 (Leakage Check: 0 overlap)
#   Fold 3: Train Pairs=40749, Val Pairs=2424 (Leakage Check: 0 overlap)
#   Fold 4: Train Pairs=39724, Val Pairs=2760 (Leakage Check: 0 overlap)
#   Fold 5: Train Pairs=39834, Val Pairs=2733 (Leakage Check: 0 overlap)
#   ℹ️  --- Fold 1/5 ---
# ✅ Stacking (Selector=True) pipeline created (using *permissive* thresholds).
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 473 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 473 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 473 -> 326 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 326 features...
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   ✅ [Selector] Completed. Final count: 2020 -> 326 (dropped 0 correlated)
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 698 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 698 features...
#   ✅ [Selector] Completed. Final count: 5120 -> 698 (dropped 0 correlated)
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 478 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 478 features...
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 476 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 476 features...
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 476 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 476 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 478 -> 333 features  - Stage 2 (Cumulative Importance, q=0.95): 476 -> 332 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 333 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 476 -> 322 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 332 features...
#
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 322 features...
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   ✅ [Selector] Completed. Final count: 2020 -> 321 (dropped 1 correlated)
#   ✅ [Selector] Completed. Final count: 2020 -> 332 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 2020 -> 333 (dropped 0 correlated)
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 670 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 670 features...
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 726 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 726 features...
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 708 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 708 features...
#   ✅ [Selector] Completed. Final count: 5120 -> 708 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 5120 -> 726 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 5120 -> 670 (dropped 0 correlated)
#
# --- Fold 1 ---
#               Metric Formatted
#             Accuracy    99.63%
#            Precision   100.00%
# Recall (Sensitivity)    99.31%
#             F1 Score    99.65%
#          Specificity   100.00%
#                  MCC    99.26%
#              ROC-AUC    99.78%
#               PR-AUC    99.89%
#   ℹ️  --- Fold 2/5 ---
# ✅ Stacking (Selector=True) pipeline created (using *permissive* thresholds).
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 474 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 474 features...
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 2 (Cumulative Importance, q=0.95): 474 -> 336 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 336 features...
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   ✅ [Selector] Completed. Final count: 2020 -> 336 (dropped 0 correlated)
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 633 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 633 features...
#   ✅ [Selector] Completed. Final count: 5120 -> 633 (dropped 0 correlated)
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 471 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 471 features...
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 477 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 477 features...
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 476 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 476 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 471 -> 335 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 335 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 477 -> 346 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 346 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 476 -> 340 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 340 features...
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   ✅ [Selector] Completed. Final count: 2020 -> 335 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 2020 -> 346 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 2020 -> 340 (dropped 0 correlated)
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 675 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 675 features...
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 650 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 650 features...
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 670 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 670 features...
#   ✅ [Selector] Completed. Final count: 5120 -> 675 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 5120 -> 650 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 5120 -> 670 (dropped 0 correlated)
#
# --- Fold 2 ---
#               Metric Formatted
#             Accuracy    99.45%
#            Precision    99.92%
# Recall (Sensitivity)    99.01%
#             F1 Score    99.47%
#          Specificity    99.92%
#                  MCC    98.90%
#              ROC-AUC    99.90%
#               PR-AUC    99.93%
#   ℹ️  --- Fold 3/5 ---
# ✅ Stacking (Selector=True) pipeline created (using *permissive* thresholds).
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 481 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 481 features...
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 481 -> 337 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 337 features...
#   ✅ [Selector] Completed. Final count: 2020 -> 337 (dropped 0 correlated)
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 697 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 697 features...
#   ✅ [Selector] Completed. Final count: 5120 -> 697 (dropped 0 correlated)
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 476 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 476 features...
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 478 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 478 features...
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 482 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 482 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 476 -> 337 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 337 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 478 -> 327 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 327 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 482 -> 329 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 329 features...
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   ✅ [Selector] Completed. Final count: 2020 -> 329 (dropped 0 correlated)
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   ✅ [Selector] Completed. Final count: 2020 -> 327 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 2020 -> 337 (dropped 0 correlated)
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 749 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 749 features...
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 679 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 679 features...
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 722 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 722 features...
#   ✅ [Selector] Completed. Final count: 5120 -> 679 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 5120 -> 722 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 5120 -> 749 (dropped 0 correlated)
#
# --- Fold 3 ---
#               Metric Formatted
#             Accuracy    99.38%
#            Precision    99.92%
# Recall (Sensitivity)    98.91%
#             F1 Score    99.42%
#          Specificity    99.91%
#                  MCC    98.76%
#              ROC-AUC    99.95%
#               PR-AUC    99.97%
#   ℹ️  --- Fold 4/5 ---
# ✅ Stacking (Selector=True) pipeline created (using *permissive* thresholds).
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 476 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 476 features...
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 476 -> 328 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 328 features...
#   ✅ [Selector] Completed. Final count: 2020 -> 328 (dropped 0 correlated)
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 608 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 608 features...
#   ✅ [Selector] Completed. Final count: 5120 -> 608 (dropped 0 correlated)
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#
#    [Config] use_variance=True, use_importance=True, use_corr=True
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 474 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 474 features...
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 475 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 475 features...
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 477 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 477 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 474 -> 337 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 337 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 475 -> 336 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 336 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 477 -> 333 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 333 features...
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   ✅ [Selector] Completed. Final count: 2020 -> 333 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 2020 -> 337 (dropped 0 correlated)
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   ✅ [Selector] Completed. Final count: 2020 -> 336 (dropped 0 correlated)
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 693 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 693 features...
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 649 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 649 features...
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 649 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 649 features...
#   ✅ [Selector] Completed. Final count: 5120 -> 649 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 5120 -> 649 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 5120 -> 693 (dropped 0 correlated)
#
# --- Fold 4 ---
#               Metric Formatted
#             Accuracy    99.06%
#            Precision    99.93%
# Recall (Sensitivity)    98.32%
#             F1 Score    99.12%
#          Specificity    99.92%
#                  MCC    98.12%
#              ROC-AUC    99.59%
#               PR-AUC    99.73%
#   ℹ️  --- Fold 5/5 ---
# ✅ Stacking (Selector=True) pipeline created (using *permissive* thresholds).
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 480 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 480 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 480 -> 338 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 338 features...
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   ✅ [Selector] Completed. Final count: 2020 -> 338 (dropped 0 correlated)
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 687 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 687 features...
#   ✅ [Selector] Completed. Final count: 5120 -> 687 (dropped 0 correlated)
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 2020)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 475 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 475 features...
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 482 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 482 features...
#   - Stage 1 (Variance, thresh=0.01): 2020 -> 480 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 480 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 480 -> 331 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 331 features...
#   - Stage 2 (Cumulative Importance, q=0.95): 482 -> 329 features  - Stage 2 (Cumulative Importance, q=0.95): 475 -> 339 features
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 339 features...
#
#   - Stage 3 (Correlation Filter, thresh=0.97): Cleaning up 329 features...
#   ✅ [Selector] Completed. Final count: 2020 -> 329 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 2020 -> 331 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 2020 -> 339 (dropped 0 correlated)
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
#    [Config] use_variance=True, use_importance=True, use_corr=True
#
# 🔥 Starting Cumulative Feature Selection (Initial: 5120)
#    [Config] use_variance=True, use_importance=True, use_corr=True
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   - Stage 1 (Variance, thresh=0.0): 5120 -> 5120 features
#   - Stage 2 (Cumulative Importance): Pre-selecting from 5120 features...
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 691 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 691 features...
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 711 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 711 features...
#   - Stage 2 (Cumulative Importance, q=0.9): 5120 -> 708 features
#   - Stage 3 (Correlation Filter, thresh=0.98): Cleaning up 708 features...
#   ✅ [Selector] Completed. Final count: 5120 -> 708 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 5120 -> 711 (dropped 0 correlated)
#   ✅ [Selector] Completed. Final count: 5120 -> 691 (dropped 0 correlated)
#   ℹ️  Generating Publication-Quality Feature Importance Plot...
#   ⚠️  Model does not expose feature_importances_; skipping importance artifacts.
#    ✅ Saved fold5_roc.png and fold5_pr.png
#   ℹ️  Saved fold5_roc.png and fold5_pr.png
#
# --- Fold 5 ---
#               Metric Formatted
#             Accuracy    99.74%
#            Precision   100.00%
# Recall (Sensitivity)    99.51%
#             F1 Score    99.76%
#          Specificity   100.00%
#                  MCC    99.49%
#              ROC-AUC    99.94%
#               PR-AUC    99.97%
# Accuracy            : 99.45%
# Precision           : 99.96%
# Recall (Sensitivity): 99.01%
# F1 Score            : 99.48%
# Specificity         : 99.95%
# MCC                 : 98.91%
# ROC-AUC             : 99.83%
# PR-AUC              : 99.90%
# {'Accuracy': 0.9945238969973869,
#  'Precision': 0.9995533510325678,
#  'Recall (Sensitivity)': 0.9901341375282133,
#  'F1 Score': 0.994817741243371,
#  'Specificity': 0.9995022967276579,
#  'MCC': 0.9890695645208197,
#  'ROC-AUC': 0.9983302993894503,
#  'PR-AUC': 0.9989671146365471}

# %% [markdown]
# ## 2) Independent Test (train=Human, test=Yeast)

# %%
indep_results = exp_run.run_experiment(
    fasta_path=BIOGRID_HUMAN_FASTA,
    pairs_path=BIOGRID_HUMAN_PAIR,
    test_fasta_path=BIOGRID_YEAST_FASTA,
    test_pairs_path=BIOGRID_YEAST_PAIR,
    h5_cache_path=H5_CACHE_FILE,
    model_factory=model_factory,
    pairing_strategy='concat',
    n_splits=1,
    esm_model_name=ESM_MODEL,
    n_jobs=N_JOBS,
    cache_version=CACHE_VERSION,
)
indep_results

# %% [markdown]
# ## 3) Full Ablation Study (5 mô hình)

# %%
ablation_df = exp_run.run_ablation_study(
    fasta_path=BIOGRID_HUMAN_FASTA,
    pairs_path=BIOGRID_HUMAN_PAIR,
    h5_cache_path=H5_CACHE_FILE,
    esm_model_name=ESM_MODEL,
    n_splits=5,
    n_jobs=N_JOBS,
)
ablation_df
